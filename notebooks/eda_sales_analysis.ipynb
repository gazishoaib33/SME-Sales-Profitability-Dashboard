# %% [markdown]
# # EDA Sales Analysis
#
# Exploratory analysis notebook for SME sales performance and profitability metrics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/sales_dataset_cleaned_with_profit.csv')
df.head()

# %%
df.describe(include='all')
